# %% [markdown]
# # Projeto para Atendimento e Suporte

# %% [markdown]
# ## Instalação das bibliotecas

# %%
# !pip install langchain langchain-groq langchain_community langchain-huggingface --q
# !pip install faiss-cpu sentence-transformers PyMuPDF python-dotenv --q
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Importações

# %%
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
import os
import getpass
from dotenv import load_dotenv

# %% [markdown]
# ## Carregamento da LLM

# %%
def load_llm(id_model, temperature):
    llm = ChatGroq(
        model=id_model,
        temperature=temperature,
        timeout=None,
        max_tokens=None,
        max_retries=2
    )
    return llm

# %%
load_dotenv(override=True)
id_model = os.getenv("ID_MODEL")
temperature = 0.7 # @param {type: "slider", min: 0.1, max: 1.5, step:: 0.1}

llm = load_llm(id_model, temperature)

# %%
prompt = "Como alterar minha senha?"

template = ChatPromptTemplate.from_messages([
    ("system", "Você é um assistente virtual prestativo e está respondendo perguntas gerais."),
    ("human", "{prompt}")
])

chain = template | llm | StrOutputParser()

res = chain.invoke({"prompt": prompt})

res
# Out:
# 'Para alterar sua senha, você precisará seguir os passos abaixo, que podem variar ligeiramente dependendo do sistema ou plataforma que você está usando. Aqui está um guia geral:\n\n### Se estiver no seu computador ou dispositivo móvel:\n\n1. **Acesse o seu perfil ou conta**: Vá para a seção de "Conta" ou "Perfil" do aplicativo ou site que você deseja alterar a senha.\n2. **Encontre a opção de alterar senha**: Procure por uma opção que diga "Alterar Senha", "Atualizar Senha" ou algo semelhante. Isso geralmente está localizado na seção de "Configurações" ou "Segurança da Conta".\n3. **Insira a senha atual**: Você precisará digitar sua senha atual para confirmar sua identidade.\n4. **Insira a nova senha**: Digite a nova senha que você deseja usar. Certifique-se de que ela atenda aos requisitos de segurança, como comprimento mínimo, uso de letras maiúsculas e minúsculas, números e símbolos.\n5. **Confirme a nova senha**: Digite a nova senha novamente para confirmar que você a digitou corretamente.\n6. **Salve as alterações**: Clique em "Salvar" ou "Atualizar" para aplicar as alterações.\n\n### Se estiver em um dispositivo móvel com um aplicativo:\n\n1. **Abra o aplicativo**: Abra o aplicativo no qual você deseja alterar a senha.\n2. **Acesse as configurações**: Toque no ícone de menu ou configurações (geralmente representado por três linhas horizontais ou um ícone de engrenagem).\n3. **Encontre a opção de alterar senha**: Procure por "Conta", "Perfil" ou "Segurança" e, em seguida, encontre a opção para alterar a senha.\n4. **Siga as instruções na tela**: O aplicativo guiará você pelo processo de alterar a senha, que geralmente inclui inserir a senha atual e então a nova senha, seguida de confirmação.\n\n### Dicas adicionais:\n\n- **Use senhas fortes**: Certifique-se de que sua nova senha seja forte e única. Evite usar informações facilmente descobríveis, como seu nome, data de nascimento ou palavras comuns.\n- **Mantenha suas senhas seguras**: Não compartilhe suas senhas com ninguém e considere usar um gerenciador de senhas para armazenar todas as suas senhas de forma segura.\n- **Ative a autenticação de dois fatores (2FA)**: Se disponível, ative a 2FA para adicionar uma camada extra de segurança à sua conta.\n\nSe tiver problemas para alterar sua senha, você pode precisar consultar a seção de ajuda do site ou aplicativo, ou entrar em contato com o suporte ao cliente para obter assistência adicional.'

# %%
def show_res(res):
    from IPython.display import Markdown

    if "</think>" in res:
        res = res.split("</think>")[-1].strip()
    else:
        res = res.strip()
    display(Markdown(res))

show_res(res)
# Out:
# Para alterar sua senha, você precisará seguir os passos abaixo, que podem variar ligeiramente dependendo do sistema ou plataforma que você está usando. Aqui está um guia geral:
#
# ### Se estiver no seu computador ou dispositivo móvel:
#
# 1. **Acesse o seu perfil ou conta**: Vá para a seção de "Conta" ou "Perfil" do aplicativo ou site que você deseja alterar a senha.
# 2. **Encontre a opção de alterar senha**: Procure por uma opção que diga "Alterar Senha", "Atualizar Senha" ou algo semelhante. Isso geralmente está localizado na seção de "Configurações" ou "Segurança da Conta".
# 3. **Insira a senha atual**: Você precisará digitar sua senha atual para confirmar sua identidade.
# 4. **Insira a nova senha**: Digite a nova senha que você deseja usar. Certifique-se de que ela atenda aos requisitos de segurança, como comprimento mínimo, uso de letras maiúsculas e minúsculas, números e símbolos.
# 5. **Confirme a nova senha**: Digite a nova senha novamente para confirmar que você a digitou corretamente.
# 6. **Salve as alterações**: Clique em "Salvar" ou "Atualizar" para aplicar as alterações.
#
# ### Se estiver em um dispositivo móvel com um aplicativo:
#
# 1. **Abra o aplicativo**: Abra o aplicativo no qual você deseja alterar a senha.
# 2. **Acesse as configurações**: Toque no ícone de menu ou configurações (geralmente representado por três linhas horizontais ou um ícone de engrenagem).
# 3. **Encontre a opção de alterar senha**: Procure por "Conta", "Perfil" ou "Segurança" e, em seguida, encontre a opção para alterar a senha.
# 4. **Siga as instruções na tela**: O aplicativo guiará você pelo processo de alterar a senha, que geralmente inclui inserir a senha atual e então a nova senha, seguida de confirmação.
#
# ### Dicas adicionais:
#
# - **Use senhas fortes**: Certifique-se de que sua nova senha seja forte e única. Evite usar informações facilmente descobríveis, como seu nome, data de nascimento ou palavras comuns.
# - **Mantenha suas senhas seguras**: Não compartilhe suas senhas com ninguém e considere usar um gerenciador de senhas para armazenar todas as suas senhas de forma segura.
# - **Ative a autenticação de dois fatores (2FA)**: Se disponível, ative a 2FA para adicionar uma camada extra de segurança à sua conta.
#
# Se tiver problemas para alterar sua senha, você pode precisar consultar a seção de ajuda do site ou aplicativo, ou entrar em contato com o suporte ao cliente para obter assistência adicional.
