# %% [markdown]
# # Projeto para departamento de Finanças - Assistente Financeiro
#
# ## Instalação das bibliotecas

# %%
# !pip install -q llama-index llama-index-llms-groq llama-index-embeddings-huggingface llama-parse
# Out:
# WARNING: huggingface-hub 1.19.0 does not provide the extra 'inference'
#
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Carregamento do modelo

# %%
from llama_index.llms.groq import Groq

# deepseek-r1-distill-llama-70b descomissionado durante o curso
llm = Groq(model="openai/gpt-oss-20b", temperature=0.1)

# %%
from llama_index.core import Settings
Settings.llm = llm

# %%
res = llm.complete("Olá, tudo legal?")
res.text
# Out:
# 'Oi! Tudo ótimo por aqui. E você, como está? Em que posso ajudar hoje?'
